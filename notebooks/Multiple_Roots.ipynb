# %% [markdown]
# <a href="https://colab.research.google.com/github/pharringtonp19/mecon/blob/main/notebooks/Multiple_Roots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Imports { display-mode: "form" }
import jax 
import jax.numpy as jnp 
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib import rcParams
rcParams['image.interpolation'] = 'nearest'
rcParams['image.cmap'] = 'viridis'
rcParams['axes.grid'] = False
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#@title Functions { display-mode: "form" }

def f0(x, y):
  return 0*x 
  
def f1(x, y): 
  return y - jnp.sin(x)

def f2(x, y):
  return y - jnp.cos(x)

def F(x, y):
  return jnp.array([f1(x,y), f2(x, y)])

# %%
#@title Plot1 { display-mode: "form" }
xp=jnp.linspace(0.,3.,50)  # N
yp=jnp.linspace(0.,3.,50)  # M
X, Y = jnp.meshgrid(xp, yp)
Z1 = f1(X,Y)
Z2 = f2(X,Y)
fig = plt.figure(dpi=300, tight_layout=True)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z1, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.plot_surface(X, Y, Z2, rstride=1, cstride=1,
                cmap='ocean', edgecolor='none')
fig.savefig('plot0.png', format='png')
plt.show()

# %%
#@title Plot1 { display-mode: "form" }
xp=jnp.linspace(0.,3.,200)  # N
yp=jnp.linspace(0.,3.,200)  # M
X, Y = jnp.meshgrid(xp, yp)
Z1 = f1(X,Y)
Z2 = f2(X,Y)
fig = plt.figure(dpi=300, tight_layout=True)
plt.contour(xp,yp,Z1,levels=[0.], colors='blue') 
plt.contour(xp,yp,Z2,levels=[0.], colors='purple')
fig.savefig('plot1.png', format='png')
plt.show()

# %%
#@title Plot2 { display-mode: "form" }
xp=jnp.linspace(-5.,5.,200)  # N
yp=jnp.linspace(-5.,5.,200)  # M
X, Y = jnp.meshgrid(xp, yp)
Z1 = f1(X,Y)
Z2 = f2(X,Y)
fig = plt.figure(dpi=300, tight_layout=True)
plt.contour(xp,yp,Z1,levels=[0.], colors='blue') 
plt.contour(xp,yp,Z2,levels=[0.], colors='purple')
fig.savefig('plot2.png', format='png')
plt.show()
